# %%
# Probability = Favorable Outcomes / Total Outcomes

f = int(input("Enter favorable outcomes: "))
t = int(input("Enter total outcomes: "))

p = f / t

print("Probability =", p)
# Out:
# Enter favorable outcomes: 2
# Enter total outcomes: 6
# Probability = 0.3333333333333333
