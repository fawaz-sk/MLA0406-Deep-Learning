# %%
name = input("Enter Student Name: ")
marks = int(input("Enter Marks: "))

if marks >= 35:
    print(name, "PASS")
else:
    print(name, "FAIL")
# Out:
# Enter Student Name: fawaz
# Enter Marks: 20
# fawaz FAIL
