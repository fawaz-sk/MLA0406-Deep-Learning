# %%
# Install required libraries

# !pip install tensorflow
# !pip install opencv-python
# !pip install matplotlib
# !pip install pillow
# !pip install scikit-learn

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba531554-8616-4ab6-9640-afd7439ba323" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba531554-8616-4ab6-9640-afd7439ba323">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("rice_images .zip.zip", "r") as zip_ref:
    zip_ref.extractall("/content")

print("Dataset Extracted Successfully!")
# Out:
# Dataset Extracted Successfully!

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Dataset path
dataset_path = "/content/rice_images.zip"

# Image preprocessing
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Training data
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=16,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation data
validation_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=16,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

print("\nDataset Loaded Successfully!")
print("\nClasses Found:")
print(train_data.class_indices)
# Out:
# Found 2686 images belonging to 4 classes.
# Found 669 images belonging to 4 classes.
#
# Dataset Loaded Successfully!
#
# Classes Found:
# {'_BrownSpot': 0, '_Healthy': 1, '_Hispa': 2, '_LeafBlast': 3}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Build CNN Model
model = Sequential([

    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(4, activation='softmax')

])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 83s 483ms/step - accuracy: 0.4475 - loss: 1.2843 - val_accuracy: 0.4200 - val_loss: 1.3134
# Epoch 2/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 80s 469ms/step - accuracy: 0.4985 - loss: 1.1868 - val_accuracy: 0.4439 - val_loss: 1.2764
# Epoch 3/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 79s 470ms/step - accuracy: 0.5112 - loss: 1.1492 - val_accuracy: 0.3528 - val_loss: 1.4600
# Epoch 4/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 82s 471ms/step - accuracy: 0.5223 - loss: 1.1236 - val_accuracy: 0.4290 - val_loss: 1.3380
# Epoch 5/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 79s 471ms/step - accuracy: 0.5268 - loss: 1.1007 - val_accuracy: 0.4185 - val_loss: 1.3300
# Epoch 6/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 79s 470ms/step - accuracy: 0.5499 - loss: 1.0732 - val_accuracy: 0.4111 - val_loss: 1.3115
# Epoch 7/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 79s 470ms/step - accuracy: 0.5737 - loss: 1.0281 - val_accuracy: 0.4215 - val_loss: 1.3527
# Epoch 8/10
# ...

# %%
# Save the trained model
model.save("rice_leaf_model.keras")

print("✅ Model Saved Successfully!")
# Out:
# ✅ Model Saved Successfully!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c622bff1-f778-4663-99d1-acf22cd2bfc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c622bff1-f778-4663-99d1-acf22cd2bfc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Get uploaded file name
img_path = list(uploaded.keys())[0]

# Load image
img = image.load_img(img_path, target_size=(128,128))
img_array = image.img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

classes = ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

predicted_class = classes[np.argmax(prediction)]
confidence = np.max(prediction) * 100

print("Prediction:", predicted_class)
print("Confidence: {:.2f}%".format(confidence))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Prediction: Healthy
# Confidence: 44.36%

# %%
disease_info = {

    "Healthy": {
        "Status": "Healthy ✅",
        "Cause": "No disease detected.",
        "Symptoms": "The leaf appears healthy.",
        "Prevention": "Maintain proper watering, nutrients and regular field monitoring.",
        "Treatment": "No treatment required."
    },

    "BrownSpot": {
        "Status": "Diseased ❌",
        "Cause": "Caused by the fungus Bipolaris oryzae.",
        "Symptoms": "Brown circular spots with yellow edges on leaves.",
        "Prevention": "Use certified seeds, maintain field drainage and apply recommended fungicides.",
        "Treatment": "Spray appropriate fungicide and remove infected leaves."
    },

    "Hispa": {
        "Status": "Diseased ❌",
        "Cause": "Caused by rice hispa insect attack.",
        "Symptoms": "White streaks and scraping damage on leaves.",
        "Prevention": "Maintain field hygiene and monitor insect populations.",
        "Treatment": "Apply recommended insecticide if infestation is severe."
    },

    "LeafBlast": {
        "Status": "Diseased ❌",
        "Cause": "Caused by the fungus Magnaporthe oryzae.",
        "Symptoms": "Diamond-shaped lesions with grey centres.",
        "Prevention": "Use resistant varieties and avoid excessive nitrogen fertilizer.",
        "Treatment": "Apply recommended fungicide and remove infected leaves."
    }
}

info = disease_info[predicted_class]

print("\n==============================")
print("🌾 Rice Leaf Disease Detection")
print("==============================")
print("Leaf Status :", info["Status"])
print("Disease Name :", predicted_class)
print("Confidence : {:.2f}%".format(confidence))
print("\nCause:")
print(info["Cause"])
print("\nSymptoms:")
print(info["Symptoms"])
print("\nPrevention:")
print(info["Prevention"])
print("\nTreatment:")
print(info["Treatment"])
# Out:
# ...
# 🌾 Rice Leaf Disease Detection
# ...
# Leaf Status : Healthy ✅
# Disease Name : Healthy
# Confidence : 44.36%
#
# Cause:
# No disease detected.
#
# Symptoms:
# The leaf appears healthy.
#
# Prevention:
# Maintain proper watering, nutrients and regular field monitoring.
#
# Treatment:
# No treatment required.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9c4673d-438f-4815-a318-edc0527f23cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9c4673d-438f-4815-a318-edc0527f23cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Get uploaded file name
img_path = list(uploaded.keys())[0]

# Load image
img = image.load_img(img_path, target_size=(128,128))
img_array = image.img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

classes = ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

predicted_class = classes[np.argmax(prediction)]
confidence = np.max(prediction) * 100

# Disease Information
disease_info = {

    "Healthy": {
        "Status": "Healthy ✅",
        "Cause": "No disease detected.",
        "Symptoms": "The leaf appears healthy.",
        "Prevention": "Maintain proper watering, nutrients and regular field monitoring.",
        "Treatment": "No treatment required."
    },

    "BrownSpot": {
        "Status": "Diseased ❌",
        "Cause": "Caused by the fungus Bipolaris oryzae.",
        "Symptoms": "Brown circular spots with yellow edges.",
        "Prevention": "Use certified seeds, maintain field drainage and apply fungicide.",
        "Treatment": "Spray appropriate fungicide."
    },

    "Hispa": {
        "Status": "Diseased ❌",
        "Cause": "Caused by rice hispa insect attack.",
        "Symptoms": "White streaks and scraping damage on leaves.",
        "Prevention": "Maintain field hygiene and monitor insect populations.",
        "Treatment": "Apply recommended insecticide."
    },

    "LeafBlast": {
        "Status": "Diseased ❌",
        "Cause": "Caused by the fungus Magnaporthe oryzae.",
        "Symptoms": "Diamond-shaped lesions on leaves.",
        "Prevention": "Use resistant varieties and avoid excessive nitrogen fertilizer.",
        "Treatment": "Apply recommended fungicide."
    }
}

info = disease_info[predicted_class]

print("\n========== Rice Leaf Disease Report ==========")
print("Leaf Status :", info["Status"])
print("Disease Name :", predicted_class)
print(f"Confidence : {confidence:.2f}%")
print("\nCause:")
print(info["Cause"])
print("\nSymptoms:")
print(info["Symptoms"])
print("\nPrevention:")
print(info["Prevention"])
print("\nTreatment:")
print(info["Treatment"])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# ========== Rice Leaf Disease Report ==========
# Leaf Status : Diseased ❌
# Disease Name : BrownSpot
# Confidence : 92.52%
#
# Cause:
# Caused by the fungus Bipolaris oryzae.
#
# Symptoms:
# Brown circular spots with yellow edges.
#
# Prevention:
# Use certified seeds, maintain field drainage and apply fungicide.
#
# Treatment:
# Spray appropriate fungicide.
